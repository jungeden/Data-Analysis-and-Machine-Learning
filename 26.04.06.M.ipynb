# %%
import pandas as pd

path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'life_expectancy.csv'

life = pd.read_csv(file)
print(life.head(3))

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression


m = 19
X = 8 * np.random.rand(m, 1) - 4
y = .5 * X ** 3 + .5 * X ** 2 + X + 3 + np.random.randn(m, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y)

poly_features = PolynomialFeatures(degree = 20, include_bias = False)
X_train_pl = poly_features.fit_transform(X_train)
X_test_pl = poly_features.fit_transform(X_test)

regr = LinearRegression()
regr.fit(X_train_pl, y_train)

print('훈련 데이터의 점수 =', f"{regr.score(X_train_pl, y_train):.3f}")
print('테스트 데이터의 점수 =', f"{regr.score(X_test_pl, y_test):.3f}")
# Out:
# 훈련 데이터의 점수 = 1.000
# 테스트 데이터의 점수 = -1220899.598

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

m = 20
X = 8 * np.random.rand(m, 1) - 4
y = .5 * X ** 3 + .5 * X ** 2 + X + 3 + np.random.randn(m, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y)

poly5 = PolynomialFeatures(degree=5, include_bias=False)
X_train_5 = poly5.fit_transform(X_train)

model5 = LinearRegression()
model5.fit(X_train_5, y_train)

print(f"5개 특성\n\n계수:{model5.coef_}\n절편:{model5.intercept_}")

poly19 = PolynomialFeatures(degree=19, include_bias=False)
X_train_19 = poly19.fit_transform(X_train)

model19 = LinearRegression()
model19.fit(X_train_19, y_train)

print(f"\n\n19개 특성\n\n계수:{model19.coef_}\n절편:{model19.intercept_}")
# Out:
# 5개 특성
#
# 계수:[[-0.12412306  0.45568903  0.68368117  0.01120653 -0.00293087]]
# 절편:[2.6525399]
#
#
# 19개 특성
#
# 계수:[[-1.57968610e+00 -3.17668033e+00  3.36850083e+00  2.10064744e+00
#    1.57638676e+00  1.07940704e+00 -1.01364914e+00 -3.82859730e-01
#   -1.34145715e+00 -3.81310958e-01  1.15789764e+00  2.06543262e-01
#   -3.57742315e-01 -3.72016550e-02  5.36785935e-02  2.72275207e-03
#   -3.88837375e-03 -6.23758372e-05  1.07171334e-04]]
# 절편:[3.77624156]
